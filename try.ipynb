# %%
import pickle
import numpy as np

with open('log_rt_backtest.pkl', 'rb') as f:
    log_rt = pickle.load(f)
    
log_rt
# Out:
# [-0.013970510463182272,
#  -0.01485995652080701,
#  -0.014465155357547206,
#  -0.016301183204721667,
#  -0.0032429041926239095,
#  -0.015279324609416018,
#  -0.012390830890326826,
#  -0.009412661152874412,
#  -0.013101159813697826,
#  -0.01116032776371966,
#  -0.011211365702857391,
#  -0.015926181331417343,
#  0.0038296343768365933,
#  -0.013888422830645113,
#  -0.010825174273407828,
#  -0.013293328495331764,
#  -0.01362202045289022,
#  -0.008852996320158717,
#  -0.012101438181353048,
#  -0.013986656459179394,
#  -0.013527287312000527,
#  -0.014302598555617059,
#  -0.012744718219242305,
#  -0.01338140237360576,
#  -0.011869881089200646,
#  -0.014330073551695991,
#  -0.012997001892597553,
#  -0.012185578381269244,
#  -0.012785142363953086,
#  -0.013426983356230902,
#  -0.030181695035777785,
#  -0.013230290953540197,
#  -0.011375452775679515,
#  -0.01389234010903801,
#  -0.013478280234715865,
#  -0.013555571043341116,
#  -0.01090960770687253,
#  -0.01566184071361373,
# ...

# %%
log_rt = np.array(log_rt)

# %%
# plot the log return
# histagram

import matplotlib.pyplot as plt

# xlim = (0, 100)
# ylim = (-0.1, 0.1)

# plt.figure(figsize=(10, 6))
log_rt.mean()
# Out:
# -0.012225390792396953

# %%
log_rt.max()
# Out:
# 0.22940617752395193

# %%
log_rt.min()
# Out:
# -5.008522654110798

# %%
(log_rt > 0).mean()
# Out:
# 0.20910031555840117

# %%
nonoutlier = log_rt[log_rt > -1]

plt.hist(nonoutlier, bins=100)
plt.show()
